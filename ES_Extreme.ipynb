# %% [markdown]
# # There is only raw data to read available for taumax = 2, 8, 16 for 95 perc and 99.5 perc 1000 surr

# %% [markdown]
# # Only the complex networks for taumax = 2, 8, 16 for 95 perc and 99.5 perc 1000 surr can be trusted

# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import matplotlib.path as mpath
import os
import sys
import time
#import h5py
import scipy.sparse

# %%
taumax2_v2 = 0
taumax4 = 0
taumax4_v2 = 0
taumax6 = 0
taumax6_v2 = 0
taumax8 = 0
taumax8_v2 = 0
taumax10 = 0
taumax10_v2 = 0
taumax12 = 0
taumax12_v2 = 0
taumax14_v2 = 0
taumax15 = 0
taumax16 = 0
taumax16_v2 = 0
taumax20 = 0
taumax20_v2 = 0
taumax25 = 0
taumax30 = 0
taumax2_v2_subseas = 0
taumax4_v2_subseas = 0
taumax6_v2_subseas = 0
taumax8_v2_subseas = 0
taumax10_v2_subseas = 0
taumax12_v2_subseas = 0
taumax14_v2_subseas = 0
taumax16_v2_subseas = 1

# %%
perc95 = 1
perc99 = 0
surr100 = 0
surr1000 = 1

# %%
if surr100:
    surr = 'surr100'
elif surr1000:
    surr = 'surr1000'

# %%
if perc95:
    perc = '95perc'
elif perc99:
    perc = '99.5perc'

# %%
file_path = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/'
file_lats = 'lats.4dx4dy_ndjfm.txt'
file_lons = 'lons.4dx4dy_ndjfm.txt'

if taumax30:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/Archiv/with_wrog_timesteps/ES_taumax30/'

    #files to read
    file_name_surrogate = 'es_surrogate_reduced.taumax30.4dx4dy.ndjfm.txt'
    file_name_real = 'es_reduced.taumax30.4dx4dy.ndjfm.txt'
    

    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax30.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+' '+surr+'.taumax30.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax30'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax30'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax30'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax30'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax30'
elif taumax25:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax25/'

    #files to read
    file_name_surrogate = 'es_surrogate_reduced.taumax25.4dx4dy.ndjfm.txt'
    file_name_real = 'es_reduced.taumax25.4dx4dy.ndjfm.txt'
    

    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax25.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax25.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax25'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax25'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax25'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax25'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax25'
elif taumax20:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax20/'

    #files to read
    file_name_surrogate = 'es_surrogate.taumax20.4dx4dy.ndjfm.txt'
    file_name_real = 'es.taumax20.4dx4dy.ndjfm.txt'
    

    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax20.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax20.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax20'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax20'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax20'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax20'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax20'
elif taumax16:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax16/'

    #files to read
    file_name_surrogate = 'es_surrogate.taumax16.4dx4dy.ndjfm.txt'
    file_name_real = 'es.taumax16.4dx4dy.ndjfm.txt'
    

    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax16.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax16.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax16'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax16'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax16'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax16'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax16'
elif taumax15:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax15/'

    #files to read
    file_name_surrogate = 'es_surrogate_reduced.taumax15.4dx4dy.ndjfm.txt'
    file_name_real = 'es_reduced.taumax15.4dx4dy.ndjfm.txt'
    

    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax15.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax15.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax15'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax15'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax15'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax15'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax15'
elif taumax12:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax12/'

    #files to read
    file_name_surrogate = 'es_surrogate.taumax12.4dx4dy.ndjfm.txt'
    file_name_real = 'es.taumax12.4dx4dy.ndjfm.txt'
    

    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax12.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax12.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax12'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax12'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax12'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax12'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax12'
elif taumax10:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax10/'

    #files to read
    file_name_surrogate = 'es_surrogate_reduced.taumax10.4dx4dy.ndjfm.txt'
    file_name_real = 'es_reduced.taumax10.4dx4dy.ndjfm.txt'
    

    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax10.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax10.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax10'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax10'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax10'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax10'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax10'
elif taumax8:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax8/'

    #files to read
    file_name_surrogate = 'es_surrogate.taumax8.4dx4dy.ndjfm.txt'
    file_name_real = 'es.taumax8.4dx4dy.ndjfm.txt'
    

    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax8.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax8.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax8'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax8'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax8'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax8'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax8'
elif taumax6:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax6/'

    #files to read
    file_name_surrogate = 'es_surrogate_reduced.taumax6.4dx4dy.ndjfm.txt'
    file_name_real = 'es_reduced.taumax6.4dx4dy.ndjfm.txt'
    

    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax6.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax6.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax6'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax6'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax6'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax6'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax6'
elif taumax4:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax4/'

    #files to read
    file_name_surrogate = 'es_surrogate.taumax4.4dx4dy.ndjfm.txt'
    file_name_real = 'es.taumax4.4dx4dy.ndjfm.txt'
    

    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax4.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax4.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax4'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax4'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax4'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax4'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax4'
elif taumax4_v2:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax4/'
    
    #files to read
    file_name_es = '_v2_es.taumax4.4dx4dy.ndjfm.txt.npz'
    file_name_sign_es = '_v2_sign_es.taumax4.4dx4dy.ndjfm.txt.npz'
    file_name_num_of_events = '0_v2_num_of_events.taumax4.4dx4dy.ndjfm.txt'
    file_name_thresh_val = '0_v2_thresh.taumax4.4dx4dy.ndjfm.txt'
    
    
    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax4.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax4.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax4'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax4'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax4'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax4'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax4'
elif taumax8_v2:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax8/'
    
    #files to read
    file_name_es = 'es.taumax8.4dx4dy.ndjfm.txt.npz'
    file_name_sign_es = 'sign_es.taumax8.4dx4dy.ndjfm.txt.npz'
    file_name_num_of_events = '0num_of_events.taumax8.4dx4dy.ndjfm.txt'
    file_name_thresh_val = '0thresh.taumax8.4dx4dy.ndjfm.txt'
    
    
    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax8.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax8.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax8'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax8'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax8'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax8'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax8'
elif taumax12_v2:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax12/'
    
    #files to read
    file_name_es = 'es.taumax12.4dx4dy.ndjfm.txt.npz'
    file_name_sign_es = 'sign_es.taumax12.4dx4dy.ndjfm.txt.npz'
    file_name_num_of_events = '0num_of_events.taumax12.4dx4dy.ndjfm.txt'
    file_name_thresh_val = '0thresh.taumax12.4dx4dy.ndjfm.txt'
    
    
    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax12.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax12.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax12'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax12'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax12'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax12'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax12'
elif taumax16_v2:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax16/'
    
    #files to read
    file_name_es = 'es.taumax16.4dx4dy.ndjfm.txt.npz'
    file_name_sign_es = 'sign_es.taumax16.4dx4dy.ndjfm.txt.npz'
    file_name_num_of_events = '0num_of_events.taumax16.4dx4dy.ndjfm.txt'
    file_name_thresh_val = '0thresh.taumax16.4dx4dy.ndjfm.txt'
    
    
    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax16.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax16.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax16'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax16'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax16'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax16'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax16'
elif taumax20_v2:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax20/'
    
    #files to read
    file_name_es = 'es.taumax20.4dx4dy.ndjfm.txt.npz'
    file_name_sign_es = 'sign_es.taumax20.4dx4dy.ndjfm.txt.npz'
    file_name_num_of_events = '0num_of_events.taumax20.4dx4dy.ndjfm.txt'
    file_name_thresh_val = '0thresh.taumax20.4dx4dy.ndjfm.txt'
    
    
    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax20.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax20.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax20'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax20'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax20'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax20'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax20'
elif taumax2_v2:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax2/'
    
    #files to read
    file_name_es = 'es.taumax2.4dx4dy.ndjfm.txt.npz'
    file_name_sign_es = 'sign_es.taumax2.4dx4dy.ndjfm.txt.npz'
    file_name_num_of_events = '0num_of_events.taumax2.4dx4dy.ndjfm.txt'
    file_name_thresh_val = '0thresh.taumax2.4dx4dy.ndjfm.txt'
    
    
    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax2.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax2.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax2'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax2'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax2'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax2'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax2'
elif taumax6_v2:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax6/'
    
    #files to read
    file_name_es = 'es.taumax6.4dx4dy.ndjfm.txt.npz'
    file_name_sign_es = 'sign_es.taumax6.4dx4dy.ndjfm.txt.npz'
    file_name_num_of_events = '0num_of_events.taumax6.4dx4dy.ndjfm.txt'
    file_name_thresh_val = '0thresh.taumax6.4dx4dy.ndjfm.txt'
    
    
    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax6.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax6.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax6'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax6'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax6'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax6'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'c_taumax6'
elif taumax10_v2:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax10/'
    
    #files to read
    file_name_es = 'es.taumax10.4dx4dy.ndjfm.txt.npz'
    file_name_sign_es = 'sign_es.taumax10.4dx4dy.ndjfm.txt.npz'
    file_name_num_of_events = '0num_of_events.taumax10.4dx4dy.ndjfm.txt'
    file_name_thresh_val = '0thresh.taumax10.4dx4dy.ndjfm.txt'
    
    
    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax10.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax10.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax10'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax10'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax10'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax10'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax10'
elif taumax14_v2:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax14/'
    
    #files to read
    file_name_es = 'es.taumax14.4dx4dy.ndjfm.txt.npz'
    file_name_sign_es = 'sign_es.taumax14.4dx4dy.ndjfm.txt.npz'
    file_name_num_of_events = '0num_of_events.taumax14.4dx4dy.ndjfm.txt'
    file_name_thresh_val = '0thresh.taumax14.4dx4dy.ndjfm.txt'
    
    
    #files to write
    file_info_about_es_field = 'es_info'+perc+'_'+surr+'.taumax14.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network'+perc+'_'+surr+'.taumax14.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax14'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax14'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax14'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax14'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax14'
    
    
elif taumax4_v2_subseas:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax4_subseas/'
    
    #files to read
    file_name_es = 'es_subseas.taumax4.4dx4dy.ndjfm.txt.npz'
    file_name_sign_es = 'sign_es_subseas.taumax4.4dx4dy.ndjfm.txt.npz'
    file_name_num_of_events = '0num_of_events_subseas.taumax4.4dx4dy.ndjfm.txt'
    file_name_thresh_val = '0thresh_subseas.taumax4.4dx4dy.ndjfm.txt'
    
    
    #files to write
    file_info_about_es_field = 'es_info_subseas'+perc+'_'+surr+'.taumax4.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network_subseas'+perc+'_'+surr+'.taumax4.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax4_subseas'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax4_subseas'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax4_subseas'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax4_subseas'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax4_subseas'
elif taumax8_v2_subseas:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax8_subseas/'
    
    #files to read
    file_name_es = 'es_subseas.taumax8.4dx4dy.ndjfm.txt.npz'
    file_name_sign_es = 'sign_es_subseas.taumax8.4dx4dy.ndjfm.txt.npz'
    file_name_num_of_events = '0num_of_events_subseas.taumax8.4dx4dy.ndjfm.txt'
    file_name_thresh_val = '0thresh_subseas.taumax8.4dx4dy.ndjfm.txt'
    
    
    #files to write
    file_info_about_es_field = 'es_info_subseas'+perc+'_'+surr+'.taumax8.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network_subseas'+perc+'_'+surr+'.taumax8.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax8_subseas'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax8_subseas'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax8_subseas'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax8_subseas'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax8_subseas'
elif taumax12_v2_subseas:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax12_subseas/'
    
    #files to read
    file_name_es = 'es_subseas.taumax12.4dx4dy.ndjfm.txt.npz'
    file_name_sign_es = 'sign_es_subseas.taumax12.4dx4dy.ndjfm.txt.npz'
    file_name_num_of_events = '0num_of_events_subseas.taumax12.4dx4dy.ndjfm.txt'
    file_name_thresh_val = '0thresh_subseas.taumax12.4dx4dy.ndjfm.txt'
    
    
    #files to write
    file_info_about_es_field = 'es_info_subseas'+perc+'_'+surr+'.taumax12.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network_subseas'+perc+'_'+surr+'.taumax12.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax12_subseas'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax12_subseas'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax12_subseas'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax12_subseas'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax12_subseas'
elif taumax16_v2_subseas:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax16_subseas/'
    
    #files to read
    file_name_es = 'es_subseas.taumax16.4dx4dy.ndjfm.txt.npz'
    file_name_sign_es = 'sign_es_subseas.taumax16.4dx4dy.ndjfm.txt.npz'
    file_name_num_of_events = '0num_of_events_subseas.taumax16.4dx4dy.ndjfm.txt'
    file_name_thresh_val = '0thresh_subseas.taumax16.4dx4dy.ndjfm.txt'
    
    
    #files to write
    file_info_about_es_field = 'es_info_subseas'+perc+'_'+surr+'.taumax16.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network_subseas'+perc+'_'+surr+'.taumax16.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax16_subseas'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax16_subseas'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax16_subseas'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax16_subseas'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax16_subseas'
elif taumax2_v2_subseas:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax2_subseas/'
    
    #files to read
    file_name_es = 'es_subseas.taumax2.4dx4dy.ndjfm.txt.npz'
    file_name_sign_es = 'sign_es_subseas.taumax2.4dx4dy.ndjfm.txt.npz'
    file_name_num_of_events = '0num_of_events_subseas.taumax2.4dx4dy.ndjfm.txt'
    file_name_thresh_val = '0thresh_subseas.taumax2.4dx4dy.ndjfm.txt'
    
    
    #files to write
    file_info_about_es_field = 'es_info_subseas'+perc+'_'+surr+'.taumax2.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network_subseas'+perc+'_'+surr+'.taumax2.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax2_subseas'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax2_subseas'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax2_subseas'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax2_subseas'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax2_subseas'
elif taumax6_v2_subseas:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax6_subseas/'
    
    #files to read
    file_name_es = 'es_subseas.taumax6.4dx4dy.ndjfm.txt.npz'
    file_name_sign_es = 'sign_es_subseas.taumax6.4dx4dy.ndjfm.txt.npz'
    file_name_num_of_events = '0num_of_events_subseas.taumax6.4dx4dy.ndjfm.txt'
    file_name_thresh_val = '0thresh_subseas.taumax6.4dx4dy.ndjfm.txt'
    
    
    #files to write
    file_info_about_es_field = 'es_info_subseas'+perc+'_'+surr+'.taumax6.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network_subseas'+perc+'_'+surr+'.taumax6.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax6_subseas'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax6_subseas'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax6_subseas'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax6_subseas'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax6_subseas'
elif taumax10_v2_subseas:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax10_subseas/'
    
    #files to read
    file_name_es = 'es_subseas.taumax10.4dx4dy.ndjfm.txt.npz'
    file_name_sign_es = 'sign_es_subseas.taumax10.4dx4dy.ndjfm.txt.npz'
    file_name_num_of_events = '0num_of_events_subseas.taumax10.4dx4dy.ndjfm.txt'
    file_name_thresh_val = '0thresh_subseas.taumax10.4dx4dy.ndjfm.txt'
    
    
    #files to write
    file_info_about_es_field = 'es_info_subseas'+perc+'_'+surr+'.taumax10.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network_subseas'+perc+'_'+surr+'.taumax10.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax10_subseas'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax10_subseas'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax10_subseas'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax10_subseas'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax10_subseas'
elif taumax14_v2_subseas:
    file_path2 = '/atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax14_subseas/'
    
    #files to read
    file_name_es = 'es_subseas.taumax14.4dx4dy.ndjfm.txt.npz'
    file_name_sign_es = 'sign_es_subseas.taumax14.4dx4dy.ndjfm.txt.npz'
    file_name_num_of_events = '0num_of_events_subseas.taumax14.4dx4dy.ndjfm.txt'
    file_name_thresh_val = '0thresh_subseas.taumax14.4dx4dy.ndjfm.txt'
    
    
    #files to write
    file_info_about_es_field = 'es_info_subseas'+perc+'_'+surr+'.taumax14.4dx4dy.ndjfm.txt'
    file_complex_network = 'complex_network_subseas'+perc+'_'+surr+'.taumax14.4dx4dy.ndjfm.txt'

    title1 = 'significant_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax14_subseas'
    title2 = 'significant_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax14_subseas'
    title3 = 'real_es_lowSLP_extreme_field_to_ny_alesund_'+perc+'_'+surr+'_taumax14_subseas'
    title4 = 'real_es_lowSLP_extreme_field_from_ny_alesund_'+perc+'_'+surr+'_taumax14_subseas'
    title5 = 'significant_es_lowSLP_extreme_field_ny_alesund_'+perc+'_'+surr+'_taumax14_subseas'

# %% [markdown]
# # testing the complex network

# %%
#start_time = time.time()
#compl_net = np.loadtxt(file_path2+file_complex_network)
#end_time = time.time()
#print("total time taken this code segment: ", end_time - start_time)

# %%
#compl_net

# %%
#compl_net.shape

# %%
#summe = 0
#for i in range(compl_net.shape[0]):
#    summe += compl_net[i,i]
#print(summe)

# %%
#compl_net.dtype

# %%
#compl_net.nbytes/10**9

# %%
#compl_net_int = compl_net.astype(np.int32)

# %%
#compl_net_int.nbytes/10**9

# %%
#compl_net_int

# %%
#compl_net_bool = compl_net.astype(np.bool_)

# %%
#compl_net_bool.nbytes/10**9

# %%
#compl_net_bool

# %% [markdown]
# # --------------------------------------------------------------------

# %%
#start_time = time.time()
#surrogate_list = []
#for i in range(5):
#    surrogate_list.append(np.loadtxt(file_path2+str(i)+file_name_surrogate))
#surrogate = np.array(surrogate_list)
#end_time = time.time()
#print("total time taken this code segment: ", end_time - start_time)

# %% [raw]
# if perc95:
#     start_time = time.time()
#     es_list = []
#     sign_es_list = []
#     for i in range(100):
#         es_list.append(scipy.sparse.load_npz(file_path2+str(i)+file_name_es))
#         sign_es_list.append(scipy.sparse.load_npz(file_path2+str(i)+file_name_sign_es))
#     end_time = time.time()
#     print('total time taken this code segment: ', end_time - start_time, ' s')
#
# elif perc99:
#     start_time = time.time()
#     es_list = []
#     sign_es_list = []
#     for i in range(100):
#         es_list.append(scipy.sparse.load_npz(file_path2+'final_es995'+str(i)+file_name_es))
#         sign_es_list.append(scipy.sparse.load_npz(file_path2+'final_es995'+str(i)+file_name_sign_es))
#     end_time = time.time()
#     print('total time taken this code segment: ', end_time - start_time, ' s')

# %% [raw]
# start_time = time.time()
# full_es_csr = sum(es_list)
# full_sign_es_csr = sum(sign_es_list)
# end_time = time.time()
# print('total time taken this code segment: ', (end_time - start_time)/60, ' min')

# %% [markdown]
# # --------------------------------------------------------------------

# %%
#surrogate0 = np.loadtxt(file_path2+str(0)+file_name_surrogate)

# %%
#surrogate0.nbytes /10**9

# %%
#hf_surrogate = h5py.File('data.hdf5', 'w')

# %%
#hf_surrogate.create_dataset('surrogate_0', data=surrogate0)

# %%
#hf_surrogate.close()

# %%
#hf_surrogate = h5py.File('data.hdf5', 'r')

# %%
#hf_surrogate.keys()

# %%
#surrogate0 = hf_surrogate.get('surrogate_0')

# %%
#type(surrogate0)

# %% [markdown]
# # --------------------------------------------------------------------

# %% [raw]
# #real_es = np.loadtxt(file_path2+file_name_real)
# real_es = full_es_csr.toarray()

# %% [raw]
# real_es.shape

# %%
lats = np.loadtxt(file_path+file_lats)
lons = np.loadtxt(file_path+file_lons)

# %% [raw]
# #surrogate.nbytes/10**9

# %% [raw]
# #es_thresh = np.percentile(surrogate, 95, axis=0)

# %% [raw]
# #significant_es = (real_es > es_thresh).astype(int)
# sign_es = full_sign_es_csr.toarray()

# %% [raw]
# sign_es.shape

# %%
print(file_path2+file_complex_network)
# Out:
# /atm_glomod/user/osahin/data/ERA5/daymean_1979-2019/NDJFM/ES_taumax16_subseas/complex_network_subseas95perc_surr1000.taumax16.4dx4dy.ndjfm.txt

# %%
sign_es = np.loadtxt(file_path2+file_complex_network)

# %%
ny_alesund_sign = sign_es[3371].reshape(80,320)   #entspricht der Event synchonization der Koordinate 78.54792,12.375 (um Ny Alesund herum) zum restlichen Feld

# %% [raw]
# ny_alesund_real = real_es[3371].reshape(80,320)   #ohne Signifikantest

# %% [markdown]
# # --------------------------------------------------------------------

# %%
#getting the lat, lon cordinates o significant nodes, that are connected to ny-alesund
lat_lon = []
for i in range(lats.shape[0]):
    for j in range(lons.shape[0]):
        lat_lon.append(np.array([lats[i], lons[j]]))
lats_lons = np.array(lat_lon)

# %% [raw]
# lats_lons.shape

# %% [raw]
# lats_lons[3371]

# %% [raw]
# filter_bool1 = sign_es[3371].astype(np.bool_)
# filter_bool2 = sign_es[:,3371].astype(np.bool_)

# %% [raw]
# filter_bool1

# %% [raw]
# filter_bool1.sum()

# %% [raw]
# lats_lons_sign1 = lats_lons[filter_bool1,:]
# lats_lons_sign2 = lats_lons[filter_bool2,:]

# %% [raw]
# lats_lons_sign1.shape

# %% [markdown]
# # --------------------------------------------------------------------

# %%
#lats_reduced = lats[:54]
#lons_reduced = lons[106:215]

# %%
#lats_reduced

# %%
#lons_reduced

# %% [raw]
# #show all significant connections from ny-alesund
# os.chdir(file_path2) # wechselt in den Ordner file_path, worin dann auch die plots landen
#
# #due to the default threshold being too large for this use case, the private _threshold attribute is divided by 100
# #smooths the connection plot
# hacked_proj = ccrs.NorthPolarStereo()
# hacked_proj._threshold /= 100.
#
# print('Events happening in a time window of #taumax days before happening in Ny-Alesund (78.54792, 12.375)')
#
# f = plt.figure(figsize=(6, 12))
# proj = hacked_proj
#
# # Compute a circle in axes coordinates, which we can use as a boundary
# # for the map. We can pan/zoom as much as we like - the boundary will be
# # permanently circular.
# theta = np.linspace(0, 2*np.pi, 100)
# center, radius = [0.5, 0.5], 0.5
# verts = np.vstack([np.sin(theta), np.cos(theta)]).T
# circle = mpath.Path(verts * radius + center)
#
# ax = plt.axes(projection=proj)
# ax.coastlines()
# ax.set_global()
#
# gl = ax.gridlines(draw_labels=False, xlocs=None, ylocs=None)  #to have smoother gridlines/latitude-lines
# gl.n_steps = 90
#
# #ax.set_title('Event synchronization of Ny-Alesund(t=0), marked by a yellow star, \n with the low slp-Extreme-Event field(-taumax<=t<0) (northern hemisphere)', fontsize=16)
# ax.gridlines()
# ax.set_extent([-180, 180, 90, 1], ccrs.PlateCarree())
# ax.set_boundary(circle, transform=ax.transAxes)
#
#
# es_cluster_extreme_map = ax.contourf(lons, lats, ny_alesund_sign, cmap=plt.cm.Reds, extend='both', transform=ccrs.PlateCarree())
#
# for coords in lats_lons_sign1:
#     plt.plot([12.375, coords[1]], [78.54792, coords[0]], color='red', linewidth=0.1, transform=ccrs.Geodetic())
#
# plt.plot(12.375, 78.54792, color='yellow', marker='*', markersize=9, transform=ccrs.Geodetic())
#
# plt.show()
#
# #f.savefig(title1 + '.png', bbox_inches='tight', dpi=f.dpi)

# %% [raw]
# #show all significant connections to ny-alesund
# os.chdir(file_path2) # wechselt in den Ordner file_path, worin dann auch die plots landen
#
# #due to the default threshold being too large for this use case, the private _threshold attribute is divided by 100
# #smooths the connection plot
# hacked_proj = ccrs.NorthPolarStereo()
# hacked_proj._threshold /= 100.
#
# print('Events happening in a time window of #taumax days after happening in Ny-Alesund (78.54792, 12.375)')
#
# f = plt.figure(figsize=(6, 12))
# proj = hacked_proj
#
# # Compute a circle in axes coordinates, which we can use as a boundary
# # for the map. We can pan/zoom as much as we like - the boundary will be
# # permanently circular.
# theta = np.linspace(0, 2*np.pi, 100)
# center, radius = [0.5, 0.5], 0.5
# verts = np.vstack([np.sin(theta), np.cos(theta)]).T
# circle = mpath.Path(verts * radius + center)
#
# ax = plt.axes(projection=proj)
# ax.coastlines()
# ax.set_global()
#
# gl = ax.gridlines(draw_labels=False, xlocs=None, ylocs=None)  #to have smoother gridlines/latitude-lines
# gl.n_steps = 90
#
# #ax.set_title('Event synchronization of Ny-Alesund(t=0), marked by a yellow star, \n with the low slp-Extreme-Event field(0<t<=taumax) (northern hemisphere)', fontsize=16)
# ax.gridlines()
# ax.set_extent([-180, 180, 90, 1], ccrs.PlateCarree())
# ax.set_boundary(circle, transform=ax.transAxes)
#
#
# es_cluster_extreme_map = ax.contourf(lons, lats, sign_es[:,3371].reshape(80,320), cmap=plt.cm.Reds, extend='both', transform=ccrs.PlateCarree())
#
# for coords in lats_lons_sign2:
#     plt.plot([12.375, coords[1]], [78.54792, coords[0]], color='red', linewidth=0.1, transform=ccrs.Geodetic())
#
# plt.plot(12.375, 78.54792, color='yellow', marker='*', markersize=9, transform=ccrs.Geodetic())
#
#
# plt.show()
#
# #f.savefig(title2 + '.png', bbox_inches='tight', dpi=f.dpi)

# %% [raw]
# full_sign_links = np.logical_or(sign_es[:,3371],sign_es[3371,:]).astype(np.int64)
# lats_lons_sign3 = lats_lons[np.logical_or(sign_es[:,3371],sign_es[3371,:]),:]

# %%
#show all significant connections to ny-alesund
os.chdir(file_path2) # wechselt in den Ordner file_path, worin dann auch die plots landen



for i in range(sign_es.shape[0]):

    filter_bool1 = sign_es[i].astype(np.bool_)
    filter_bool2 = sign_es[:,i].astype(np.bool_)

    lats_lons_sign1 = lats_lons[filter_bool1,:]
    lats_lons_sign2 = lats_lons[filter_bool2,:]

    full_sign_links = np.logical_or(sign_es[:,i],sign_es[i,:]).astype(np.int64)
    lats_lons_sign3 = lats_lons[np.logical_or(sign_es[:,i],sign_es[i,:]),:]

    #due to the default threshold being too large for this use case, the private _threshold attribute is divided by 100
    #smooths the connection plot 
    hacked_proj = ccrs.NorthPolarStereo()
    hacked_proj._threshold /= 100.

    #print('Events happening in a time window of #taumax days before and after happening in Ny-Alesund (78.54792, 12.375)')

    f = plt.figure(figsize=(6, 12))
    proj = hacked_proj   
   
    # Compute a circle in axes coordinates, which we can use as a boundary
    # for the map. We can pan/zoom as much as we like - the boundary will be
    # permanently circular.
    theta = np.linspace(0, 2*np.pi, 100)
    center, radius = [0.5, 0.5], 0.5
    verts = np.vstack([np.sin(theta), np.cos(theta)]).T
    circle = mpath.Path(verts * radius + center)
    
    ax = plt.axes(projection=proj)
    ax.coastlines()
    ax.set_global()
 
    gl = ax.gridlines(draw_labels=False, xlocs=None, ylocs=None)  #to have smoother gridlines/latitude-lines
    gl.n_steps = 90
    
    #ax.set_title('Event synchronization of Ny-Alesund(t=0), marked by a yellow star, \n with the low slp-Extreme-Event field(-taumax<=t<=taumax) (northern hemisphere)', fontsize=16)
    ax.gridlines()
    ax.set_extent([-180, 180, 90, 1], ccrs.PlateCarree())
    ax.set_boundary(circle, transform=ax.transAxes)

      
    es_cluster_extreme_map = ax.contourf(lons, lats, full_sign_links.reshape(80,320), cmap=plt.cm.Reds, extend='both', transform=ccrs.PlateCarree())#,levels=[0,1])

    for coords in lats_lons_sign3:
        #plt.plot([12.375, coords[1]], [78.54792, coords[0]], color='red', linewidth=0.1, transform=ccrs.Geodetic())
        plt.plot([lats_lons[i][1], coords[1]], [lats_lons[i][0], coords[0]], color='red', linewidth=0.1, transform=ccrs.Geodetic())


#plt.plot(12.375, 78.54792, color='yellow', marker='*', markersize=9, transform=ccrs.Geodetic())

    
plt.show()
   
#f.savefig(title5 + '.png', bbox_inches='tight', dpi=f.dpi)
# Out:
# /home/osahin/anaconda3/envs/myenv/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %% [raw]
# #show all connections from ny-alesund
# os.chdir(file_path2) # wechselt in den Ordner file_path, worin dann auch die plots landen
#
# #due to the default threshold being too large for this use case, the private _threshold attribute is divided by 100
# #smooths the connection plot
# hacked_proj = ccrs.NorthPolarStereo()
# hacked_proj._threshold /= 100.
#
# print('Events happening in a time window of #taumax days before happening in Ny-Alesund (78.54792, 12.375)')
#
# f = plt.figure(figsize=(6, 12))
# proj = hacked_proj
#
# # Compute a circle in axes coordinates, which we can use as a boundary
# # for the map. We can pan/zoom as much as we like - the boundary will be
# # permanently circular.
# theta = np.linspace(0, 2*np.pi, 100)
# center, radius = [0.5, 0.5], 0.5
# verts = np.vstack([np.sin(theta), np.cos(theta)]).T
# circle = mpath.Path(verts * radius + center)
#
# ax = plt.axes(projection=proj)
# ax.coastlines()
# ax.set_global()
#
# gl = ax.gridlines(draw_labels=False, xlocs=None, ylocs=None)  #to have smoother gridlines/latitude-lines
# gl.n_steps = 90
#
# #ax.set_title('Event synchronization of Ny-Alesund(t=0), marked by a yellow star, \n with the low slp-Extreme-Event field(-taumax<=t<0) (northern hemisphere)', fontsize=16)
# ax.gridlines()
# ax.set_extent([-180, 180, 90, 1], ccrs.PlateCarree())
# ax.set_boundary(circle, transform=ax.transAxes)
#
#
# es_extreme_map = ax.contourf(lons, lats, ny_alesund_real, cmap=plt.cm.Reds, extend='both', transform=ccrs.PlateCarree())
# plt.plot(12.375, 78.54792, color='yellow', marker='*', markersize=9, transform=ccrs.Geodetic())
#
# cmap = plt.colorbar(es_extreme_map, ax=ax, orientation="horizontal", shrink=0.7 )
# cmap.set_label('Event synchronization',size=12)
#
# plt.show()
#
# f.savefig(title3 + '.png', bbox_inches='tight', dpi=f.dpi)

# %% [raw]
# #show all connections to ny-alesund
# os.chdir(file_path2) # wechselt in den Ordner file_path, worin dann auch die plots landen
#
# #due to the default threshold being too large for this use case, the private _threshold attribute is divided by 100
# #smooths the connection plot
# hacked_proj = ccrs.NorthPolarStereo()
# hacked_proj._threshold /= 100.
#
# print('Events happening in a time window of #taumax days after happening in Ny-Alesund (78.54792, 12.375)')
#
# f = plt.figure(figsize=(6, 12))
# proj = hacked_proj
#
# # Compute a circle in axes coordinates, which we can use as a boundary
# # for the map. We can pan/zoom as much as we like - the boundary will be
# # permanently circular.
# theta = np.linspace(0, 2*np.pi, 100)
# center, radius = [0.5, 0.5], 0.5
# verts = np.vstack([np.sin(theta), np.cos(theta)]).T
# circle = mpath.Path(verts * radius + center)
#
# ax = plt.axes(projection=proj)
# ax.coastlines()
# ax.set_global()
#
# gl = ax.gridlines(draw_labels=False, xlocs=None, ylocs=None)  #to have smoother gridlines/latitude-lines
# gl.n_steps = 90
#
# #ax.set_title('Event synchronization of Ny-Alesund(t=0), marked by a yellow star, \n with the low slp-Extreme-Event field(0<t<=taumax) (northern hemisphere)', fontsize=16)
# ax.gridlines()
# ax.set_extent([-180, 180, 90, 1], ccrs.PlateCarree())
# ax.set_boundary(circle, transform=ax.transAxes)
#
#
# es_extreme_map = ax.contourf(lons, lats, real_es[:,3371].reshape(80,320), cmap=plt.cm.Reds, extend='both', transform=ccrs.PlateCarree())
# plt.plot(12.375, 78.54792, color='yellow', marker='*', markersize=9, transform=ccrs.Geodetic())
#
# cmap = plt.colorbar(es_extreme_map, ax=ax, orientation="horizontal", shrink=0.7 )
# cmap.set_label('Event synchronization',size=12)
#
# plt.show()
#
# f.savefig(title4 + '.png', bbox_inches='tight', dpi=f.dpi)

# %% [raw]
# sign_number_of_links = np.count_nonzero(sign_es) #number of links in es-adjacency matrix after surroate significance testing
# sign_number_of_links

# %% [raw]
# number_of_links = np.count_nonzero(real_es) #number of links in es-adjacency matrix
# number_of_links

# %% [raw]
# percentage_sign_links = (sign_number_of_links/number_of_links)*100  #percentage of significant links in adjacency matrix
# percentage_sign_links

# %% [raw]
# info_arr = np.array([sign_number_of_links, number_of_links, percentage_sign_links])

# %% [raw]
# np.savetxt(file_path2+file_info_about_es_field, info_arr)

# %% [raw]
# sign_es

# %% [raw]
# start_time = time.time()
# np.savetxt(file_path2+file_complex_network, sign_es)
# end_time = time.time()
# print('total time taken this code segment: ', (end_time - start_time)/60, ' min')

# %% [raw]
# # -----------------------------------------------------------------------------------------

# %% [raw]
# sign_es.sum(axis=1)

# %% [raw]
# sign_es[3371].sum()

# %% [raw]
# np.argwhere(sign_es.sum(axis=1)==sign_es.sum(axis=1).max())

# %% [raw]
# np.mod(3468,320)

# %% [raw]
# (3468-268)/320

# %% [raw]
# 10*320+268

# %% [raw]
# #np.set_printoptions(threshold=sys.maxsize)

# %% [raw]
# np.argsort(sign_es.sum(axis=1))

# %% [raw]
# sign_es.sum(axis=1)[10685]
